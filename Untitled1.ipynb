# %% [markdown]
# <a href="https://colab.research.google.com/github/AntF2/Actividad/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.1/486.1 kB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 17.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 28.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 8.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.3/258.3 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 30.7 MB/s eta 0:00:00
# ...

# %%
from pycaret import regression
import pandas as pd
import matplotlib.pyplot as plt

# %%
datos = pd.read_csv("datos.csv")
datos
# Out:
#          Character   Universe  Strength  Speed  Intelligence SpecialAbilities  \
# 0     Wonder Woman     Marvel         7      8             3      Telekinesis
# 1         Iron Man     Marvel         4      7             9      Telekinesis
# 2         Iron Man  DC Comics         8      7             5      Telekinesis
# 3       Spider-Man  DC Comics         5      6            10      Telekinesis
# 4            Flash     Marvel         7      6             2     Invisibility
# ...            ...        ...       ...    ...           ...              ...
# 2346      Superman  DC Comics         9      8             5   Super Strength
# 2347      Superman  DC Comics         2      5             8   Super Strength
# 2348         Flash  DC Comics         5      3             3      Telekinesis
# 2349        Batman  DC Comics         5     10             6           Flight
# 2350    Spider-Man     Marvel         8      1             5   Super Strength
#
# ...

# %%
plt.figure(figsize=(10, 6))
datos.boxplot(column=['Strength', 'Speed', 'Intelligence'])
plt.title('Diagrama de Estadisticas')
plt.ylabel('Valores')
plt.show()

# %%
reg1 = regression.setup(
    data = datos,
    target = "Speed",
    numeric_imputation = "mean",
    remove_outliers = True,
    train_size = 0.75,
    polynomial_features = True,
    polynomial_degree = 2,
    rare_to_value = 0.1,
    feature_selection = True,
    n_features_to_select = 0.8,
    pca = True,
    pca_components = 8,
    normalize = True,
    normalize_method = "zscore"
)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000268 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2040
# [LightGBM] [Info] Number of data points in the train set: 1674, number of used features: 8
# [LightGBM] [Info] Start training from score 5.500000
# <style type="text/css">
# #T_e8392_row9_col1, #T_e8392_row15_col1, #T_e8392_row17_col1, #T_e8392_row19_col1, #T_e8392_row21_col1, #T_e8392_row24_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e8392" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8392_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e8392_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8392_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
best_model = regression.compare_models(sort = "mse")
# Out:
# <style type="text/css">
# #T_38b57 th {
#   text-align: left;
# }
# ...

# %%
reg2 = regression.setup(
    data = datos,
    target = "Speed",
    numeric_imputation = "mean",
    remove_outliers = True,
    train_size = 0.75,
    polynomial_features = True,
    polynomial_degree = 2,
    rare_to_value = 0.1,
    feature_selection = False,
    pca = True,
    pca_components = 8,
    normalize = True,
    normalize_method = "zscore"
)
# Out:
# <style type="text/css">
# #T_a805c_row9_col1, #T_a805c_row15_col1, #T_a805c_row17_col1, #T_a805c_row19_col1, #T_a805c_row21_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a805c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a805c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a805c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a805c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a805c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a805c_row0_col1" class="data row0 col1" >7843</td>
#     </tr>
#     <tr>
#       <th id="T_a805c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a805c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a805c_row1_col1" class="data row1 col1" >Speed</td>
#     </tr>
#     <tr>
# ...

# %%
best_model = regression.compare_models(sort = "mse")
# Out:
# <style type="text/css">
# #T_3731d th {
#   text-align: left;
# }
# ...

# %%
reg3 = regression.setup(
    data = datos,
    target = "Speed",
    numeric_imputation = "mean",
    remove_outliers = True,
    train_size = 0.75,
    polynomial_features = True,
    polynomial_degree = 2,
    rare_to_value = 0.1,
    feature_selection = True,
    n_features_to_select = 0.8,
    pca = False,
    normalize = True,
    normalize_method = "zscore"
)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003746 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 966
# [LightGBM] [Info] Number of data points in the train set: 1674, number of used features: 190
# [LightGBM] [Info] Start training from score 5.370968
# <style type="text/css">
# #T_21e47_row9_col1, #T_21e47_row15_col1, #T_21e47_row17_col1, #T_21e47_row19_col1, #T_21e47_row21_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_21e47" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21e47_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_21e47_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
best_model = regression.compare_models(sort = "mse")
# Out:
# <style type="text/css">
# #T_68a00 th {
#   text-align: left;
# }
# ...

# %%
reg4 = regression.setup(
    data = datos,
    target = "Speed",
    numeric_imputation = "mean",
    remove_outliers = True,
    train_size = 0.75,
    polynomial_features = True,
    polynomial_degree = 2,
    rare_to_value = 0.1,
    feature_selection = True,
    n_features_to_select = 0.8,
    pca = True,
    pca_components = 8,
    normalize = True,
    normalize_method = "zscore",
    remove_multicolinearity = True
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-3fc0bc61f297> in <cell line: 1>()
# ----> 1 reg4 = regression.setup(
#       2     data = datos,
#       3     target = "Speed",
#       4     numeric_imputation = "mean",
#       5     remove_outliers = True,
#
# TypeError: setup() got an unexpected keyword argument 'remove_multicolinearity'

# %%
best_model = regression.compare_models(sort = "R2")
# Out:
# <style type="text/css">
# #T_e3998 th {
#   text-align: left;
# }
# ...
